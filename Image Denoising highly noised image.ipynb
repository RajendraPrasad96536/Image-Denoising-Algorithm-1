# %% [markdown]
# <a href="https://colab.research.google.com/github/RajendraPrasad96536/Image-Denoising-Algorithm-1/blob/master/Image%20Denoising%20highly%20noised%20image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
from tensorflow import keras
from keras.optimizers import RMSprop, Adagrad, Adam
from keras.layers import Conv2D, Input, Dense, Dropout, MaxPool2D, UpSampling2D
from keras.layers import Conv2DTranspose, BatchNormalization, add, LeakyReLU
from keras.models import Model
from keras.datasets import cifar10
from keras.callbacks import ModelCheckpoint
import keras.layers as layers
from keras.initializers import orthogonal

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(cifar_train, _), (cifar_test, _) = cifar10.load_data()

# %%
size = 32
channel = 3
# scaling input data
cifar_train = cifar_train / 255
cifar_test = cifar_test / 255

# Adding noise mean = 0, std = 0.6
noise = 0.3
cifar_train_noise = cifar_train + noise * np.random.normal(0, 0.6, size=cifar_train.shape) 
cifar_test_noise = cifar_test + noise * np.random.normal(0, 0.6, size=cifar_test.shape)

cifar_train_noise = np.clip(cifar_train_noise, 0, 1)
cifar_test_noise = np.clip(cifar_test_noise, 0, 1)

# %%
# Visualize few training images with their noisy images

rows = 2 # defining no. of rows in figure
cols = 6# defining no. of colums in figure

f = plt.figure(figsize=(2*cols,2*rows*2)) # defining a figure 

for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*2,cols, (2*i*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_train_noise[i*cols + j]) 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*2,cols,((2*i+1)*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_train[i*cols + j]) 
        plt.axis("off")
        
f.suptitle("Sample Training Data",fontsize=18)
plt.savefig("Cifar-trian.png")

plt.show()

# %%
inputs = Input(shape=(size,size,channel))
def Model_1():
  x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
  x = BatchNormalization()(x)
  x = MaxPool2D()(x)
  x = Dropout(0.5)(x)
  skip = Conv2D(32, 3, padding='same')(x) # skip connection for decoder
  x = LeakyReLU()(skip)
  x = BatchNormalization()(x)
  x = MaxPool2D()(x)
  x = Dropout(0.5)(x)
  x = Conv2D(64, 3, activation='relu', padding='same')(x)
  x = BatchNormalization()(x)
  encoded = MaxPool2D()(x)

  # Decoder
  x = Conv2DTranspose(64, 3,activation='relu',strides=(2,2), padding='same')(encoded)
  x = BatchNormalization()(x)
  x = Dropout(0.5)(x)
  x = Conv2DTranspose(32, 3, activation='relu',strides=(2,2), padding='same')(x)
  x = BatchNormalization()(x)
  x = Dropout(0.5)(x)
  x = Conv2DTranspose(32, 3, padding='same')(x)
  x = add([x,skip]) # adding skip connection
  x = LeakyReLU()(x)
  x = BatchNormalization()(x)
  decoded = Conv2DTranspose(3, 3, activation='sigmoid',strides=(2,2), padding='same')(x)
  return decoded



def Conv2DLayer(x, filters, kernel, strides, padding, block_id, kernel_init=orthogonal()):
    prefix = f'block_{block_id}_'
    x = layers.Conv2D(filters, kernel_size=kernel, strides=strides, padding=padding,
                      kernel_initializer=kernel_init, name=prefix+'conv')(x)
    x = layers.LeakyReLU(name=prefix+'lrelu')(x)
    x = layers.Dropout(0.2, name=prefix+'drop')((x))
    x = layers.BatchNormalization(name=prefix+'conv_bn')(x)
    return x

def Transpose_Conv2D(x, filters, kernel, strides, padding, block_id, kernel_init=orthogonal()):
    prefix = f'block_{block_id}_'
    x = layers.Conv2DTranspose(filters, kernel_size=kernel, strides=strides, padding=padding,
                               kernel_initializer=kernel_init, name=prefix+'de-conv')(x)
    x = layers.LeakyReLU(name=prefix+'lrelu')(x)
    x = layers.Dropout(0.2, name=prefix+'drop')((x))
    x = layers.BatchNormalization(name=prefix+'conv_bn')(x)
    return x


def Model_2():

    conv1 = Conv2DLayer(inputs, 64, 3, strides=1, padding='same', block_id=1)
    conv2 = Conv2DLayer(conv1, 64, 3, strides=2, padding='same', block_id=2)
  
    conv3 = Conv2DLayer(conv2, 128, 5, strides=2, padding='same', block_id=3)
    
    conv4 = Conv2DLayer(conv3, 128, 3, strides=1, padding='same', block_id=4)
    conv5 = Conv2DLayer(conv4, 256, 5, strides=2, padding='same', block_id=5)
    
    conv6 = Conv2DLayer(conv5, 512, 3, strides=2, padding='same', block_id=6)
    
    deconv1 = Transpose_Conv2D(conv6, 512, 3, strides=2, padding='same', block_id=7)
    
    skip1 = layers.concatenate([deconv1, conv5], name='skip1')
    conv7 = Conv2DLayer(skip1, 256, 3, strides=1, padding='same', block_id=8)
    deconv2 = Transpose_Conv2D(conv7, 128, 3, strides=2, padding='same', block_id=9)
    
    skip2 = layers.concatenate([deconv2, conv3], name='skip2')
    conv8 = Conv2DLayer(skip2, 128, 5, strides=1, padding='same', block_id=10)
    deconv3 = Transpose_Conv2D(conv8, 64, 3, strides=2, padding='same', block_id=11)
    
    skip3 = layers.concatenate([deconv3, conv2], name='skip3')
    conv9 = Conv2DLayer(skip3, 64, 5, strides=1, padding='same', block_id=12)
    deconv4 = Transpose_Conv2D(conv9, 64, 3, strides=2, padding='same', block_id=13)
    
    skip4 = layers.concatenate([deconv4, conv1])
    conv10 = layers.Conv2D(3, 3, strides=1, padding='same', activation='sigmoid',
                       kernel_initializer=orthogonal(), name='final_conv')(skip4)

    return conv10

# %%
checkpoint = ModelCheckpoint('best_model_final.h5', verbose=1, save_best_only=True, save_weights_only=True)

# %%
# Encoder 
decoder = Model_2()

#decoder = Model_1()
model = Model(inputs, decoder)

""""
optimizer = keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False
)

optimizer = keras.optimizers.Adagrad(
    learning_rate=0.01,
    initial_accumulator_value=0.1,
    epsilon=1e-07
)
"""
#optimizer = Adam(lr=0.001,decay=0.001/80)
optimizer = keras.optimizers.Adamax(lr=0.001)
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)

#optimizer = keras.optimizers.SGD(learning_rate=lr_schedule)

#model_opt = Adam(lr_schedule)
model.compile(optimizer=optimizer,loss='mean_squared_error')
#model.compile(loss='mean_squared_error', optimizer = RMSprop())
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block_1_conv (Conv2D)           (None, 32, 32, 64)   1792        input_2[0][0]
# __________________________________________________________________________________________________
# block_1_lrelu (LeakyReLU)       (None, 32, 32, 64)   0           block_1_conv[0][0]
# __________________________________________________________________________________________________
# block_1_drop (Dropout)          (None, 32, 32, 64)   0           block_1_lrelu[0][0]
# __________________________________________________________________________________________________
# block_1_conv_bn (BatchNormaliza (None, 32, 32, 64)   256         block_1_drop[0][0]
# __________________________________________________________________________________________________
# block_2_conv (Conv2D)           (None, 16, 16, 64)   36928       block_1_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_2_lrelu (LeakyReLU)       (None, 16, 16, 64)   0           block_2_conv[0][0]
# __________________________________________________________________________________________________
# block_2_drop (Dropout)          (None, 16, 16, 64)   0           block_2_lrelu[0][0]
# __________________________________________________________________________________________________
# block_2_conv_bn (BatchNormaliza (None, 16, 16, 64)   256         block_2_drop[0][0]
# __________________________________________________________________________________________________
# block_3_conv (Conv2D)           (None, 8, 8, 128)    204928      block_2_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_3_lrelu (LeakyReLU)       (None, 8, 8, 128)    0           block_3_conv[0][0]
# __________________________________________________________________________________________________
# block_3_drop (Dropout)          (None, 8, 8, 128)    0           block_3_lrelu[0][0]
# __________________________________________________________________________________________________
# block_3_conv_bn (BatchNormaliza (None, 8, 8, 128)    512         block_3_drop[0][0]
# __________________________________________________________________________________________________
# block_4_conv (Conv2D)           (None, 8, 8, 128)    147584      block_3_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_4_lrelu (LeakyReLU)       (None, 8, 8, 128)    0           block_4_conv[0][0]
# __________________________________________________________________________________________________
# block_4_drop (Dropout)          (None, 8, 8, 128)    0           block_4_lrelu[0][0]
# __________________________________________________________________________________________________
# block_4_conv_bn (BatchNormaliza (None, 8, 8, 128)    512         block_4_drop[0][0]
# __________________________________________________________________________________________________
# block_5_conv (Conv2D)           (None, 4, 4, 256)    819456      block_4_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_5_lrelu (LeakyReLU)       (None, 4, 4, 256)    0           block_5_conv[0][0]
# __________________________________________________________________________________________________
# block_5_drop (Dropout)          (None, 4, 4, 256)    0           block_5_lrelu[0][0]
# __________________________________________________________________________________________________
# block_5_conv_bn (BatchNormaliza (None, 4, 4, 256)    1024        block_5_drop[0][0]
# __________________________________________________________________________________________________
# block_6_conv (Conv2D)           (None, 2, 2, 512)    1180160     block_5_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_6_lrelu (LeakyReLU)       (None, 2, 2, 512)    0           block_6_conv[0][0]
# __________________________________________________________________________________________________
# block_6_drop (Dropout)          (None, 2, 2, 512)    0           block_6_lrelu[0][0]
# __________________________________________________________________________________________________
# block_6_conv_bn (BatchNormaliza (None, 2, 2, 512)    2048        block_6_drop[0][0]
# __________________________________________________________________________________________________
# block_7_de-conv (Conv2DTranspos (None, 4, 4, 512)    2359808     block_6_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_7_lrelu (LeakyReLU)       (None, 4, 4, 512)    0           block_7_de-conv[0][0]
# __________________________________________________________________________________________________
# block_7_drop (Dropout)          (None, 4, 4, 512)    0           block_7_lrelu[0][0]
# __________________________________________________________________________________________________
# block_7_conv_bn (BatchNormaliza (None, 4, 4, 512)    2048        block_7_drop[0][0]
# __________________________________________________________________________________________________
# skip1 (Concatenate)             (None, 4, 4, 768)    0           block_7_conv_bn[0][0]
#                                                                  block_5_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_8_conv (Conv2D)           (None, 4, 4, 256)    1769728     skip1[0][0]
# __________________________________________________________________________________________________
# block_8_lrelu (LeakyReLU)       (None, 4, 4, 256)    0           block_8_conv[0][0]
# __________________________________________________________________________________________________
# block_8_drop (Dropout)          (None, 4, 4, 256)    0           block_8_lrelu[0][0]
# __________________________________________________________________________________________________
# block_8_conv_bn (BatchNormaliza (None, 4, 4, 256)    1024        block_8_drop[0][0]
# __________________________________________________________________________________________________
# block_9_de-conv (Conv2DTranspos (None, 8, 8, 128)    295040      block_8_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_9_lrelu (LeakyReLU)       (None, 8, 8, 128)    0           block_9_de-conv[0][0]
# __________________________________________________________________________________________________
# block_9_drop (Dropout)          (None, 8, 8, 128)    0           block_9_lrelu[0][0]
# __________________________________________________________________________________________________
# block_9_conv_bn (BatchNormaliza (None, 8, 8, 128)    512         block_9_drop[0][0]
# __________________________________________________________________________________________________
# skip2 (Concatenate)             (None, 8, 8, 256)    0           block_9_conv_bn[0][0]
#                                                                  block_3_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_10_conv (Conv2D)          (None, 8, 8, 128)    819328      skip2[0][0]
# __________________________________________________________________________________________________
# block_10_lrelu (LeakyReLU)      (None, 8, 8, 128)    0           block_10_conv[0][0]
# __________________________________________________________________________________________________
# block_10_drop (Dropout)         (None, 8, 8, 128)    0           block_10_lrelu[0][0]
# __________________________________________________________________________________________________
# block_10_conv_bn (BatchNormaliz (None, 8, 8, 128)    512         block_10_drop[0][0]
# __________________________________________________________________________________________________
# block_11_de-conv (Conv2DTranspo (None, 16, 16, 64)   73792       block_10_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_11_lrelu (LeakyReLU)      (None, 16, 16, 64)   0           block_11_de-conv[0][0]
# __________________________________________________________________________________________________
# block_11_drop (Dropout)         (None, 16, 16, 64)   0           block_11_lrelu[0][0]
# __________________________________________________________________________________________________
# block_11_conv_bn (BatchNormaliz (None, 16, 16, 64)   256         block_11_drop[0][0]
# __________________________________________________________________________________________________
# skip3 (Concatenate)             (None, 16, 16, 128)  0           block_11_conv_bn[0][0]
#                                                                  block_2_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_12_conv (Conv2D)          (None, 16, 16, 64)   204864      skip3[0][0]
# __________________________________________________________________________________________________
# block_12_lrelu (LeakyReLU)      (None, 16, 16, 64)   0           block_12_conv[0][0]
# __________________________________________________________________________________________________
# block_12_drop (Dropout)         (None, 16, 16, 64)   0           block_12_lrelu[0][0]
# __________________________________________________________________________________________________
# block_12_conv_bn (BatchNormaliz (None, 16, 16, 64)   256         block_12_drop[0][0]
# __________________________________________________________________________________________________
# block_13_de-conv (Conv2DTranspo (None, 32, 32, 64)   36928       block_12_conv_bn[0][0]
# __________________________________________________________________________________________________
# block_13_lrelu (LeakyReLU)      (None, 32, 32, 64)   0           block_13_de-conv[0][0]
# __________________________________________________________________________________________________
# block_13_drop (Dropout)         (None, 32, 32, 64)   0           block_13_lrelu[0][0]
# __________________________________________________________________________________________________
# block_13_conv_bn (BatchNormaliz (None, 32, 32, 64)   256         block_13_drop[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           block_13_conv_bn[0][0]
#                                                                  block_1_conv_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 32, 32, 3)    3459        concatenate_2[0][0]
# ==================================================================================================
# Total params: 7,963,267
# Trainable params: 7,958,531
# Non-trainable params: 4,736
# __________________________________________________________________________________________________

# %%
# Training
epochs = 180
batch_size = 128
history = model.fit(cifar_train_noise,
                cifar_train,
                epochs=epochs,
                batch_size=batch_size,
                shuffle=True,
                validation_data=(cifar_test_noise, cifar_test),
                callbacks=[checkpoint]
               )
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/180
# 50000/50000 [==============================] - 45s 899us/step - loss: 0.0102 - val_loss: 0.0173
#
# Epoch 00001: val_loss improved from inf to 0.01726, saving model to best_model_final.h5
# Epoch 2/180
# 50000/50000 [==============================] - 43s 852us/step - loss: 0.0060 - val_loss: 0.0047
#
# Epoch 00002: val_loss improved from 0.01726 to 0.00467, saving model to best_model_final.h5
# Epoch 3/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0050 - val_loss: 0.0040
#
# Epoch 00003: val_loss improved from 0.00467 to 0.00404, saving model to best_model_final.h5
# Epoch 4/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0045 - val_loss: 0.0040
#
# Epoch 00004: val_loss improved from 0.00404 to 0.00400, saving model to best_model_final.h5
# Epoch 5/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0043 - val_loss: 0.0039
#
# Epoch 00005: val_loss improved from 0.00400 to 0.00393, saving model to best_model_final.h5
# Epoch 6/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0041 - val_loss: 0.0036
#
# Epoch 00006: val_loss improved from 0.00393 to 0.00361, saving model to best_model_final.h5
# Epoch 7/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0040 - val_loss: 0.0036
#
# Epoch 00007: val_loss did not improve from 0.00361
# Epoch 8/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0039 - val_loss: 0.0039
#
# Epoch 00008: val_loss did not improve from 0.00361
# Epoch 9/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0039 - val_loss: 0.0034
#
# Epoch 00009: val_loss improved from 0.00361 to 0.00342, saving model to best_model_final.h5
# Epoch 10/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0038 - val_loss: 0.0033
#
# Epoch 00010: val_loss improved from 0.00342 to 0.00333, saving model to best_model_final.h5
# Epoch 11/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0038 - val_loss: 0.0033
#
# Epoch 00011: val_loss did not improve from 0.00333
# Epoch 12/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0037 - val_loss: 0.0033
#
# Epoch 00012: val_loss improved from 0.00333 to 0.00332, saving model to best_model_final.h5
# Epoch 13/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0037 - val_loss: 0.0033
#
# Epoch 00013: val_loss improved from 0.00332 to 0.00326, saving model to best_model_final.h5
# Epoch 14/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0037 - val_loss: 0.0033
#
# Epoch 00014: val_loss did not improve from 0.00326
# Epoch 15/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0036 - val_loss: 0.0032
#
# Epoch 00015: val_loss improved from 0.00326 to 0.00320, saving model to best_model_final.h5
# Epoch 16/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0036 - val_loss: 0.0032
#
# Epoch 00016: val_loss improved from 0.00320 to 0.00316, saving model to best_model_final.h5
# Epoch 17/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0036 - val_loss: 0.0032
#
# Epoch 00017: val_loss did not improve from 0.00316
# Epoch 18/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0036 - val_loss: 0.0033
#
# Epoch 00018: val_loss did not improve from 0.00316
# Epoch 19/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0036 - val_loss: 0.0032
#
# Epoch 00019: val_loss improved from 0.00316 to 0.00316, saving model to best_model_final.h5
# Epoch 20/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0035 - val_loss: 0.0032
#
# Epoch 00020: val_loss did not improve from 0.00316
# Epoch 21/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0035 - val_loss: 0.0032
#
# Epoch 00021: val_loss did not improve from 0.00316
# Epoch 22/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0035 - val_loss: 0.0033
#
# Epoch 00022: val_loss did not improve from 0.00316
# Epoch 23/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00023: val_loss improved from 0.00316 to 0.00312, saving model to best_model_final.h5
# Epoch 24/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00024: val_loss improved from 0.00312 to 0.00308, saving model to best_model_final.h5
# Epoch 25/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00025: val_loss improved from 0.00308 to 0.00307, saving model to best_model_final.h5
# Epoch 26/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00026: val_loss did not improve from 0.00307
# Epoch 27/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00027: val_loss improved from 0.00307 to 0.00307, saving model to best_model_final.h5
# Epoch 28/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00028: val_loss improved from 0.00307 to 0.00307, saving model to best_model_final.h5
# Epoch 29/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00029: val_loss did not improve from 0.00307
# Epoch 30/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0035 - val_loss: 0.0030
#
# Epoch 00030: val_loss improved from 0.00307 to 0.00304, saving model to best_model_final.h5
# Epoch 31/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00031: val_loss did not improve from 0.00304
# Epoch 32/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0034 - val_loss: 0.0031
#
# Epoch 00032: val_loss did not improve from 0.00304
# Epoch 33/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00033: val_loss improved from 0.00304 to 0.00302, saving model to best_model_final.h5
# Epoch 34/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0034 - val_loss: 0.0032
#
# Epoch 00034: val_loss did not improve from 0.00302
# Epoch 35/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0034 - val_loss: 0.0031
#
# Epoch 00035: val_loss did not improve from 0.00302
# Epoch 36/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0034 - val_loss: 0.0031
#
# Epoch 00036: val_loss did not improve from 0.00302
# Epoch 37/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00037: val_loss did not improve from 0.00302
# Epoch 38/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00038: val_loss improved from 0.00302 to 0.00302, saving model to best_model_final.h5
# Epoch 39/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00039: val_loss did not improve from 0.00302
# Epoch 40/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00040: val_loss improved from 0.00302 to 0.00300, saving model to best_model_final.h5
# Epoch 41/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00041: val_loss did not improve from 0.00300
# Epoch 42/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00042: val_loss improved from 0.00300 to 0.00299, saving model to best_model_final.h5
# Epoch 43/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00043: val_loss did not improve from 0.00299
# Epoch 44/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00044: val_loss improved from 0.00299 to 0.00299, saving model to best_model_final.h5
# Epoch 45/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00045: val_loss did not improve from 0.00299
# Epoch 46/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00046: val_loss did not improve from 0.00299
# Epoch 47/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00047: val_loss improved from 0.00299 to 0.00298, saving model to best_model_final.h5
# Epoch 48/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00048: val_loss improved from 0.00298 to 0.00296, saving model to best_model_final.h5
# Epoch 49/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00049: val_loss did not improve from 0.00296
# Epoch 50/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00050: val_loss improved from 0.00296 to 0.00296, saving model to best_model_final.h5
# Epoch 51/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00051: val_loss did not improve from 0.00296
# Epoch 52/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0034 - val_loss: 0.0029
#
# Epoch 00052: val_loss improved from 0.00296 to 0.00295, saving model to best_model_final.h5
# Epoch 53/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00053: val_loss improved from 0.00295 to 0.00293, saving model to best_model_final.h5
# Epoch 54/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00054: val_loss did not improve from 0.00293
# Epoch 55/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00055: val_loss did not improve from 0.00293
# Epoch 56/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00056: val_loss did not improve from 0.00293
# Epoch 57/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00057: val_loss did not improve from 0.00293
# Epoch 58/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00058: val_loss did not improve from 0.00293
# Epoch 59/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00059: val_loss did not improve from 0.00293
# Epoch 60/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00060: val_loss did not improve from 0.00293
# Epoch 61/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00061: val_loss did not improve from 0.00293
# Epoch 62/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00062: val_loss did not improve from 0.00293
# Epoch 63/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00063: val_loss did not improve from 0.00293
# Epoch 64/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00064: val_loss did not improve from 0.00293
# Epoch 65/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00065: val_loss did not improve from 0.00293
# Epoch 66/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00066: val_loss did not improve from 0.00293
# Epoch 67/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00067: val_loss did not improve from 0.00293
# Epoch 68/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00068: val_loss did not improve from 0.00293
# Epoch 69/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00069: val_loss did not improve from 0.00293
# Epoch 70/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00070: val_loss did not improve from 0.00293
# Epoch 71/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00071: val_loss did not improve from 0.00293
# Epoch 72/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00072: val_loss did not improve from 0.00293
# Epoch 73/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00073: val_loss did not improve from 0.00293
# Epoch 74/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00074: val_loss improved from 0.00293 to 0.00293, saving model to best_model_final.h5
# Epoch 75/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00075: val_loss improved from 0.00293 to 0.00292, saving model to best_model_final.h5
# Epoch 76/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00076: val_loss did not improve from 0.00292
# Epoch 77/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00077: val_loss did not improve from 0.00292
# Epoch 78/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00078: val_loss did not improve from 0.00292
# Epoch 79/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00079: val_loss did not improve from 0.00292
# Epoch 80/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00080: val_loss did not improve from 0.00292
# Epoch 81/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00081: val_loss did not improve from 0.00292
# Epoch 82/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00082: val_loss did not improve from 0.00292
# Epoch 83/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00083: val_loss did not improve from 0.00292
# Epoch 84/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00084: val_loss did not improve from 0.00292
# Epoch 85/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00085: val_loss improved from 0.00292 to 0.00291, saving model to best_model_final.h5
# Epoch 86/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00086: val_loss did not improve from 0.00291
# Epoch 87/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00087: val_loss did not improve from 0.00291
# Epoch 88/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00088: val_loss did not improve from 0.00291
# Epoch 89/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00089: val_loss did not improve from 0.00291
# Epoch 90/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00090: val_loss did not improve from 0.00291
# Epoch 91/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00091: val_loss did not improve from 0.00291
# Epoch 92/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00092: val_loss did not improve from 0.00291
# Epoch 93/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00093: val_loss did not improve from 0.00291
# Epoch 94/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00094: val_loss did not improve from 0.00291
# Epoch 95/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00095: val_loss did not improve from 0.00291
# Epoch 96/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00096: val_loss did not improve from 0.00291
# Epoch 97/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00097: val_loss did not improve from 0.00291
# Epoch 98/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00098: val_loss did not improve from 0.00291
# Epoch 99/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00099: val_loss did not improve from 0.00291
# Epoch 100/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00100: val_loss did not improve from 0.00291
# Epoch 101/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00101: val_loss did not improve from 0.00291
# Epoch 102/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00102: val_loss improved from 0.00291 to 0.00291, saving model to best_model_final.h5
# Epoch 103/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00103: val_loss did not improve from 0.00291
# Epoch 104/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00104: val_loss did not improve from 0.00291
# Epoch 105/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00105: val_loss did not improve from 0.00291
# Epoch 106/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00106: val_loss did not improve from 0.00291
# Epoch 107/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00107: val_loss did not improve from 0.00291
# Epoch 108/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00108: val_loss did not improve from 0.00291
# Epoch 109/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00109: val_loss improved from 0.00291 to 0.00290, saving model to best_model_final.h5
# Epoch 110/180
# 50000/50000 [==============================] - 43s 860us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00110: val_loss did not improve from 0.00290
# Epoch 111/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00111: val_loss did not improve from 0.00290
# Epoch 112/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00112: val_loss did not improve from 0.00290
# Epoch 113/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00113: val_loss did not improve from 0.00290
# Epoch 114/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00114: val_loss did not improve from 0.00290
# Epoch 115/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00115: val_loss did not improve from 0.00290
# Epoch 116/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00116: val_loss did not improve from 0.00290
# Epoch 117/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00117: val_loss did not improve from 0.00290
# Epoch 118/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0032
#
# Epoch 00118: val_loss did not improve from 0.00290
# Epoch 119/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00119: val_loss did not improve from 0.00290
# Epoch 120/180
# 50000/50000 [==============================] - 43s 864us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00120: val_loss did not improve from 0.00290
# Epoch 121/180
# 50000/50000 [==============================] - 43s 860us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00121: val_loss did not improve from 0.00290
# Epoch 122/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00122: val_loss did not improve from 0.00290
# Epoch 123/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00123: val_loss did not improve from 0.00290
# Epoch 124/180
# 50000/50000 [==============================] - 43s 859us/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00124: val_loss did not improve from 0.00290
# Epoch 125/180
# 50000/50000 [==============================] - 43s 859us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00125: val_loss improved from 0.00290 to 0.00290, saving model to best_model_final.h5
# Epoch 126/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00126: val_loss did not improve from 0.00290
# Epoch 127/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00127: val_loss did not improve from 0.00290
# Epoch 128/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00128: val_loss did not improve from 0.00290
# Epoch 129/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00129: val_loss did not improve from 0.00290
# Epoch 130/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00130: val_loss improved from 0.00290 to 0.00289, saving model to best_model_final.h5
# Epoch 131/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00131: val_loss did not improve from 0.00289
# Epoch 132/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00132: val_loss did not improve from 0.00289
# Epoch 133/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00133: val_loss improved from 0.00289 to 0.00289, saving model to best_model_final.h5
# Epoch 134/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00134: val_loss improved from 0.00289 to 0.00288, saving model to best_model_final.h5
# Epoch 135/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00135: val_loss did not improve from 0.00288
# Epoch 136/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00136: val_loss did not improve from 0.00288
# Epoch 137/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00137: val_loss did not improve from 0.00288
# Epoch 138/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00138: val_loss did not improve from 0.00288
# Epoch 139/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00139: val_loss did not improve from 0.00288
# Epoch 140/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00140: val_loss did not improve from 0.00288
# Epoch 141/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00141: val_loss did not improve from 0.00288
# Epoch 142/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00142: val_loss did not improve from 0.00288
# Epoch 143/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0032 - val_loss: 0.0030
#
# Epoch 00143: val_loss did not improve from 0.00288
# Epoch 144/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00144: val_loss did not improve from 0.00288
# Epoch 145/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0030
#
# Epoch 00145: val_loss did not improve from 0.00288
# Epoch 146/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00146: val_loss did not improve from 0.00288
# Epoch 147/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00147: val_loss did not improve from 0.00288
# Epoch 148/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00148: val_loss did not improve from 0.00288
# Epoch 149/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00149: val_loss improved from 0.00288 to 0.00288, saving model to best_model_final.h5
# Epoch 150/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00150: val_loss did not improve from 0.00288
# Epoch 151/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00151: val_loss did not improve from 0.00288
# Epoch 152/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00152: val_loss did not improve from 0.00288
# Epoch 153/180
# 50000/50000 [==============================] - 43s 860us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00153: val_loss did not improve from 0.00288
# Epoch 154/180
# 50000/50000 [==============================] - 43s 859us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00154: val_loss did not improve from 0.00288
# Epoch 155/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00155: val_loss did not improve from 0.00288
# Epoch 156/180
# 50000/50000 [==============================] - 43s 858us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00156: val_loss did not improve from 0.00288
# Epoch 157/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00157: val_loss did not improve from 0.00288
# Epoch 158/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00158: val_loss did not improve from 0.00288
# Epoch 159/180
# 50000/50000 [==============================] - 43s 859us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00159: val_loss did not improve from 0.00288
# Epoch 160/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00160: val_loss improved from 0.00288 to 0.00288, saving model to best_model_final.h5
# Epoch 161/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00161: val_loss did not improve from 0.00288
# Epoch 162/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00162: val_loss did not improve from 0.00288
# Epoch 163/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00163: val_loss did not improve from 0.00288
# Epoch 164/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00164: val_loss did not improve from 0.00288
# Epoch 165/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0030
#
# Epoch 00165: val_loss did not improve from 0.00288
# Epoch 166/180
# 50000/50000 [==============================] - 43s 853us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00166: val_loss did not improve from 0.00288
# Epoch 167/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00167: val_loss did not improve from 0.00288
# Epoch 168/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00168: val_loss did not improve from 0.00288
# Epoch 169/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00169: val_loss did not improve from 0.00288
# Epoch 170/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00170: val_loss did not improve from 0.00288
# Epoch 171/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0030
#
# Epoch 00171: val_loss did not improve from 0.00288
# Epoch 172/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00172: val_loss did not improve from 0.00288
# Epoch 173/180
# 50000/50000 [==============================] - 43s 857us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00173: val_loss did not improve from 0.00288
# Epoch 174/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00174: val_loss did not improve from 0.00288
# Epoch 175/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00175: val_loss did not improve from 0.00288
# Epoch 176/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00176: val_loss improved from 0.00288 to 0.00288, saving model to best_model_final.h5
# Epoch 177/180
# 50000/50000 [==============================] - 43s 854us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00177: val_loss improved from 0.00288 to 0.00288, saving model to best_model_final.h5
# Epoch 178/180
# 50000/50000 [==============================] - 43s 856us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00178: val_loss did not improve from 0.00288
# Epoch 179/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00179: val_loss did not improve from 0.00288
# Epoch 180/180
# 50000/50000 [==============================] - 43s 855us/step - loss: 0.0032 - val_loss: 0.0029
#
# Epoch 00180: val_loss did not improve from 0.00288

# %%
# Defining Figure
f = plt.figure(figsize=(10,7))
f.add_subplot()

#Adding Subplot
plt.plot(history.epoch, history.history['loss'], label = "loss") # Loss curve for training set
plt.plot(history.epoch, history.history['val_loss'], label = "val_loss") # Loss curve for validation set

plt.title("Loss Curve",fontsize=18)
plt.xlabel("Epochs",fontsize=15)
plt.ylabel("Loss",fontsize=15)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig("Loss_curve_cifar10.png")
plt.show()

# %%
def mse(data_1, data_2):
   return np.square(np.subtract(data_1, data_2)).mean()

# %%
import random
import tensorflow as tf
for i in range(20):
  index = random.randint(0, 10000)
  orig_images = cifar_test[index] 
  noised_original = cifar_test_noise[index]
  noised_original_1 = noised_original.reshape(1,32,32,3)
  test_desoided = model.predict(noised_original_1)
  denoised_image  = test_desoided.reshape(32,32,3)

  import matplotlib.pyplot as plt 
  # %matplotlib inline
  
  fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(9,3))

  axes[0].imshow(orig_images)
  axes[0].set_title('Original image')

  axes[1].imshow(noised_original)
  mse1 = round(mse(orig_images, noised_original), 5)
  psnr1 = round(tf.image.psnr(orig_images,noised_original,max_val=1.0).numpy(), 3)
  axes[1].set_title('Noised image \n MSE = {0:8.5f} \n PSNR = {1:8.2f}'.format(mse1, psnr1))
  mse2 = round(mse(denoised_image, orig_images), 5)
  psnr2 = round(tf.image.psnr(orig_images,denoised_image,max_val=1.0).numpy(), 3) 
  axes[2].imshow(denoised_image)
  axes[2].set_title('Denoised image \n MSE = {0:8.5f} \n PSNR = {1:8.2f}'.format(mse2, psnr2))
  plt.savefig("image"+str(i)+".png")
  plt.show()
